# %% [markdown]
# <a href="https://colab.research.google.com/github/majid55321/Scientific-Cal-by-Majid-Ali/blob/main/Scientific_Calculator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math
import sympy as sp

# Define available operations
def add(x, y):
    return x + y

def subtract(x, y):
    return x - y

def multiply(x, y):
    return x * y

def divide(x, y):
    if y == 0:
        return "Error: Division by zero"
    return x / y

def power(x, y):
    return math.pow(x, y)

def factorial(x):
    if x < 0:
        return "Error: Factorial of negative number"
    return math.factorial(x)

def sin(x):
    return math.sin(math.radians(x))

def cos(x):
    return math.cos(math.radians(x))

def tan(x):
    return math.tan(math.radians(x))

def log(x, base=10):
    if x <= 0:
        return "Error: Logarithm of non-positive number"
    return math.log(x, base)

def exp(x):
    return math.exp(x)

def sqrt(x):
    if x < 0:
        return "Error: Square root of negative number"
    return math.sqrt(x)

def simplify(expr):
    return sp.simplify(expr)

def solve(equation, variable):
    return sp.solve(equation, variable)

# Menu for the calculator
def calculator():
    print("Scientific Calculator (fx-991ES PLUS style)")
    print("Select operation:")
    print("1. Add")
    print("2. Subtract")
    print("3. Multiply")
    print("4. Divide")
    print("5. Power (x^y)")
    print("6. Factorial")
    print("7. Sin")
    print("8. Cos")
    print("9. Tan")
    print("10. Logarithm")
    print("11. Exponential (e^x)")
    print("12. Square Root")
    print("13. Simplify Expression")
    print("14. Solve Equation")
    print("0. Exit")

    while True:
        choice = input("\nEnter choice (0-14): ")

        if choice == '0':
            print("Exiting the calculator.")
            break

        if choice in ['1', '2', '3', '4', '5']:
            num1 = float(input("Enter first number: "))
            num2 = float(input("Enter second number: "))
            if choice == '1':
                print(f"Result: {add(num1, num2)}")
            elif choice == '2':
                print(f"Result: {subtract(num1, num2)}")
            elif choice == '3':
                print(f"Result: {multiply(num1, num2)}")
            elif choice == '4':
                print(f"Result: {divide(num1, num2)}")
            elif choice == '5':
                print(f"Result: {power(num1, num2)}")

        elif choice == '6':
            num = int(input("Enter a number: "))
            print(f"Result: {factorial(num)}")

        elif choice == '7':
            angle = float(input("Enter an angle in degrees: "))
            print(f"Result: {sin(angle)}")

        elif choice == '8':
            angle = float(input("Enter an angle in degrees: "))
            print(f"Result: {cos(angle)}")

        elif choice == '9':
            angle = float(input("Enter an angle in degrees: "))
            print(f"Result: {tan(angle)}")

        elif choice == '10':
            num = float(input("Enter a number: "))
            base = float(input("Enter the base (default is 10): ") or 10)
            print(f"Result: {log(num, base)}")

        elif choice == '11':
            num = float(input("Enter a number: "))
            print(f"Result: {exp(num)}")

        elif choice == '12':
            num = float(input("Enter a number: "))
            print(f"Result: {sqrt(num)}")

        elif choice == '13':
            expr = input("Enter an expression to simplify: ")
            result = simplify(expr)
            print(f"Simplified Expression: {result}")

        elif choice == '14':
            equation = input("Enter an equation (e.g., x^2 - 4 = 0): ")
            variable = input("Enter the variable to solve for (e.g., x): ")
            result = solve(sp.sympify(equation), sp.Symbol(variable))
            print(f"Solution: {result}")

        else:
            print("Invalid Input")

# Run the calculator
calculator()
# Out:
# Scientific Calculator (fx-991ES PLUS style)
# Select operation:
# 1. Add
# 2. Subtract
# 3. Multiply
# 4. Divide
# 5. Power (x^y)
# 6. Factorial
# 7. Sin
# 8. Cos
# 9. Tan
# 10. Logarithm
# 11. Exponential (e^x)
# 12. Square Root
# 13. Simplify Expression
# 14. Solve Equation
# 0. Exit
#
# Enter choice (0-14): 5
# Enter first number: 3
# Enter second number: 2
# Result: 9.0
#
# Enter choice (0-14): 0
# Exiting the calculator.
